# %%
import pandas as pd
import numpy as np
df2=pd.read_table('university_towns.txt')
df2.head()
# Out:
#                                      Alabama[edit]
# 0                    Auburn (Auburn University)[1]
# 1           Florence (University of North Alabama)
# 2  Jacksonville (Jacksonville State University)[2]
# 3       Livingston (University of West Alabama)[2]
# 4         Montevallo (University of Montevallo)[2]

# %%
df2['Alabama[edit]'] = df2['Alabama[edit]'].str.replace(r'\[.*?\]','').str.replace(r"\(.*\)","")
df2=df2.rename(columns={'Alabama[edit]': 'Alabama'})
df2
# Out:
#                            Alabama
# 0                          Auburn
# 1                        Florence
# 2                    Jacksonville
# 3                      Livingston
# 4                      Montevallo
# 5                            Troy
# 6                      Tuscaloosa
# 7                        Tuskegee
# 8                           Alaska
# 9                       Fairbanks
# 10                         Arizona
# 11                      Flagstaff
# 12                          Tempe
# 13                         Tucson
# 14                        Arkansas
# 15                    Arkadelphia
# 16                         Conway
# 17                   Fayetteville
# 18                      Jonesboro
# 19                       Magnolia
# 20                     Monticello
# 21                   Russellville
# 22                         Searcy
# 23                      California
# 24                         Angwin
# 25                         Arcata
# ...

# %%
df=pd.read_table('university_towns.txt', header=-1)
df.head()
# Out:
#                                                  0
# 0                                    Alabama[edit]
# 1                    Auburn (Auburn University)[1]
# 2           Florence (University of North Alabama)
# 3  Jacksonville (Jacksonville State University)[2]
# 4       Livingston (University of West Alabama)[2]

# %%
import re
def Uni_t():
    with open('university_towns.txt') as file:
        data = []
        for line in file:

            data.append(line[:-1])
    state_town = []
    for line in data:
        if line[-6:] == '[edit]':       
            state = line[:-6]
            state = re.sub("[^\x20-\x7E]", "", state)
        elif '(' in line:
            town = line[:line.index('(')-1]
            state_town.append([state,town])        
        else:
            town = line
            state_town.append([state,town])
    state_college_df = pd.DataFrame(state_town,columns = ['State','RegionName'])
    return state_college_df
Uni_t()

# %%
import pandas as pd
import numpy as np
gdp = pd.read_excel('gdplev.xls', skiprows=5)
gdp.head()
# Out:
#    Unnamed: 0  GDP in billions of current dollars  \
# 0         NaN                                 NaN
# 1         NaN                                 NaN
# 2      1929.0                               104.6
# 3      1930.0                                92.2
# 4      1931.0                                77.4
#
#    GDP in billions of chained 2009 dollars  Unnamed: 3 Unnamed: 4  \
# 0                                      NaN         NaN        NaN
# 1                                      NaN         NaN        NaN
# 2                                   1056.6         NaN     1947q1
# 3                                    966.7         NaN     1947q2
# 4                                    904.8         NaN     1947q3
#
#    GDP in billions of current dollars.1  \
# 0                                   NaN
# 1                                   NaN
# 2                                 243.1
# 3                                 246.3
# 4                                 250.1
#
# ...

# %%
gdp.loc[3]['GDP in billions of chained 2009 dollars.1']
len(gdp)
# Out:
# 280
