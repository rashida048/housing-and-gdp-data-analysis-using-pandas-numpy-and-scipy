# %%
import pandas as pd
train = pd.read_csv('http://bit.ly/kaggletrain')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train['Embarked_num'] = train.Embarked.map({'S':1, 'C':2, 'Q':3})
train.loc[0:4, ['Embarked', 'Embarked_num']]
# Out:
#   Embarked  Embarked_num
# 0        S           1.0
# 1        C           2.0
# 2        S           1.0
# 3        S           1.0
# 4        S           1.0

# %%
train['Sex_num']= train.Sex.map({'female':1, 'male':0})
train.loc[0:4, ['Sex', 'Sex_num']]
# Out:
#       Sex  Sex_num
# 0    male        0
# 1  female        1
# 2  female        1
# 3  female        1
# 4    male        0

# %%
train['Name_length']=train.Name.apply(len)
train.loc[0:4, ['Name', 'Name_length']]
# Out:
#                                                 Name  Name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
import numpy as np
train['Fare_ceil']=train.Fare.apply(np.ceil)
train.loc[0:4, ['Fare', 'Fare_ceil']]
# Out:
#       Fare  Fare_ceil
# 0   7.2500        8.0
# 1  71.2833       72.0
# 2   7.9250        8.0
# 3  53.1000       54.0
# 4   8.0500        9.0

# %%
train.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
def get_element(my_list, position):
    return my_list[position]

# %%
train.Name.str.split(',').apply(get_element, position=0).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
train.Name.str.split(',').apply(get_element, position=1).head()
# Out:
# 0                                Mr. Owen Harris
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# Name: Name, dtype: object

# %%
train.Cabin.str.split('').head()
# Out:
# 0                 NaN
# 1       [, C, 8, 5, ]
# 2                 NaN
# 3    [, C, 1, 2, 3, ]
# 4                 NaN
# Name: Cabin, dtype: object

# %%
train.Name.str.split(',').apply(lambda x:x[0]).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
train.Name.str.split(',').apply(lambda x:x[1]).head()
# Out:
# 0                                Mr. Owen Harris
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# Name: Name, dtype: object

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=1).head()
# Out:
# 0      0
# 1    132
# 2     25
# 3    312
# 4    217
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=1).head()
# Out:
# 0      beer_servings
# 1    spirit_servings
# 2      beer_servings
# 3      wine_servings
# 4      beer_servings
# dtype: object

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=0).head()
# Out:
# beer_servings      117
# spirit_servings     68
# wine_servings       61
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float).head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0

# %%
drinks.loc[:, 'beer_servings':'wine_servings']=drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float).head()

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
##Adding 3 dollars to the values

# %%
def add3(x):
    return x+3

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(add3).head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            3.0              3.0            3.0
# 1           92.0            135.0           57.0
# 2           28.0              3.0           17.0
# 3          248.0            141.0          315.0
# 4          220.0             60.0           48.0

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(lambda x:x+3).head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            3.0              3.0            3.0
# 1           92.0            135.0           57.0
# 2           28.0              3.0           17.0
# 3          248.0            141.0          315.0
# 4          220.0             60.0           48.0

# %%
df=pd.DataFrame({'A':['1.1B', '3.6B', '1.2B'],
                'B':['2.3B', '3.5B', '4.1B'],
                'C':['1.5B', '3.7B', '2.9B']},
               index=[1,2,3])
df
# Out:
#       A     B     C
# 1  1.1B  2.3B  1.5B
# 2  3.6B  3.5B  3.7B
# 3  1.2B  4.1B  2.9B

# %%
df1=df.applymap(lambda x:x[:-1])
df1
# Out:
#      A    B    C
# 1  1.1  2.3  1.5
# 2  3.6  3.5  3.7
# 3  1.2  4.1  2.9

# %%
def convert(x):
    return int(x)

# %%
mySeries=pd.Series([100,200,300,450,390,700,870,np.nan])
mySeries
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3    450.0
# 4    390.0
# 5    700.0
# 6    870.0
# 7      NaN
# dtype: float64

# %%
mySeries.map(add3)
# Out:
# 0    103.0
# 1    203.0
# 2    303.0
# 3    453.0
# 4    393.0
# 5    703.0
# 6    873.0
# 7      NaN
# dtype: float64

# %%
mySeries.map(add3, na_action='ignore')
# Out:
# 0    103.0
# 1    203.0
# 2    303.0
# 3    453.0
# 4    393.0
# 5    703.0
# 6    873.0
# 7      NaN
# dtype: float64

# %%
mySeries.map(add3, na_action='None')
# Out:
# 0    103.0
# 1    203.0
# 2    303.0
# 3    453.0
# 4    393.0
# 5    703.0
# 6    873.0
# 7      NaN
# dtype: float64

# %%
mySeries.map(lambda x: 'This is {}'.format(x), na_action='ignore')
# Out:
# 0    This is 100.0
# 1    This is 200.0
# 2    This is 300.0
# 3    This is 450.0
# 4    This is 390.0
# 5    This is 700.0
# 6    This is 870.0
# 7              NaN
# dtype: object

# %%
data = {'first_name':['David', 'Meera', 'Shahana', 'Amina', 'Lunia'],
       'age': [22,40,62,18,56],
       'city': ['Dhaka', 'Miami', 'Houston', 'Boston', 'Hollywood']}
df=pd.DataFrame(data,columns=['first_name', 'age', 'city'])
df
# Out:
#   first_name  age       city
# 0      David   22      Dhaka
# 1      Meera   40      Miami
# 2    Shahana   62    Houston
# 3      Amina   18     Boston
# 4      Lunia   56  Hollywood

# %%
capitalizer = lambda x: x.upper()
df['FN']=df['first_name'].apply(capitalizer)
df
# Out:
#   first_name  age       city       FN
# 0      David   22      Dhaka    DAVID
# 1      Meera   40      Miami    MEERA
# 2    Shahana   62    Houston  SHAHANA
# 3      Amina   18     Boston    AMINA
# 4      Lunia   56  Hollywood    LUNIA

# %%
data1={'height':[72,23,67,45,60],
      'age':[26,4,56,10,14]}
df3=pd.DataFrame(data1, columns=['height', 'age'])
df3
# Out:
#    height  age
# 0      72   26
# 1      23    4
# 2      67   56
# 3      45   10
# 4      60   14

# %%
df3.applymap(np.sqrt)
# Out:
#      height       age
# 0  8.485281  5.099020
# 1  4.795832  2.000000
# 2  8.185353  7.483315
# 3  6.708204  3.162278
# 4  7.745967  3.741657
